# %% [markdown]
# # Validation

# %%
import pandas as pd

# %%
# Paths
xls_path = "/home/tatiane/repositorios/brazil-health-data-project/data_pipeline/data/raw/ibge_codigos/RELATORIO_DTB_BRASIL_2024_MUNICIPIOS.xls"
parquet_path = "/home/tatiane/repositorios/brazil-health-data-project/data_pipeline/data/processed/ibge_codigos/RELATORIO_DTB_BRASIL_2024_MUNICIPIOS.parquet"

# %%
# Reading
df_xls = pd.read_excel(xls_path)
df_parquet = pd.read_parquet(parquet_path)

# %% [markdown]
# - Validation

# %%
print('Quantidade de registros do Dataset xls:', len(df_xls))
print('Quantidade de registros do Dataset parquet:', len(df_parquet))
# Out:
# Quantidade de registros do Dataset xls: 5571
# Quantidade de registros do Dataset parquet: 5571

# %%
print('Colunas do Dataset xls:' , df_xls.columns.tolist())
# Out:
# Colunas do Dataset xls: ['UF', 'Nome_UF', 'Região Geográfica Intermediária', 'Nome Região Geográfica Intermediária', 'Região Geográfica Imediata', 'Nome Região Geográfica Imediata', 'Município', 'Código Município Completo', 'Nome_Município', 'Unnamed: 9']

# %%
print('Colunas do Dataset parquet:' , df_parquet.columns.tolist())
# Out:
# Colunas do Dataset parquet: ['UF', 'Nome_UF', 'Região Geográfica Intermediária', 'Nome Região Geográfica Intermediária', 'Região Geográfica Imediata', 'Nome Região Geográfica Imediata', 'Município', 'Código Município Completo', 'Nome_Município', 'Unnamed: 9']

# %%
df_xls.head(20)
# Out:
#     UF   Nome_UF  Região Geográfica Intermediária  \
# 0   11  Rondônia                             1102
# 1   11  Rondônia                             1102
# 2   11  Rondônia                             1101
# 3   11  Rondônia                             1102
# 4   11  Rondônia                             1101
# 5   11  Rondônia                             1101
# 6   11  Rondônia                             1102
# 7   11  Rondônia                             1101
# 8   11  Rondônia                             1102
# 9   11  Rondônia                             1101
# 10  11  Rondônia                             1101
# 11  11  Rondônia                             1102
# 12  11  Rondônia                             1102
# 13  11  Rondônia                             1102
# 14  11  Rondônia                             1102
# 15  11  Rondônia                             1102
# 16  11  Rondônia                             1102
# 17  11  Rondônia                             1101
# ...

# %%
df_parquet.head(20)
# Out:
#     UF   Nome_UF  Região Geográfica Intermediária  \
# 0   11  Rondônia                             1102
# 1   11  Rondônia                             1102
# 2   11  Rondônia                             1101
# 3   11  Rondônia                             1102
# 4   11  Rondônia                             1101
# 5   11  Rondônia                             1101
# 6   11  Rondônia                             1102
# 7   11  Rondônia                             1101
# 8   11  Rondônia                             1102
# 9   11  Rondônia                             1101
# 10  11  Rondônia                             1101
# 11  11  Rondônia                             1102
# 12  11  Rondônia                             1102
# 13  11  Rondônia                             1102
# 14  11  Rondônia                             1102
# 15  11  Rondônia                             1102
# 16  11  Rondônia                             1102
# 17  11  Rondônia                             1101
# ...
