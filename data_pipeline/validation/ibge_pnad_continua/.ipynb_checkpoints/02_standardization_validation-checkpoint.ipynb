# %% [markdown]
# # Validation

# %%
import pandas as pd
import re

# %%
# Paths
PATH = '/home/tatiane/repositorios/brazil-health-data-project/data_pipeline'
raw_path = f"{PATH}/data/raw/ibge_pnad_continua/tabela5436.csv"

# %%
# Reading
raw = pd.read_csv(raw_path, sep=",", encoding="latin1")

# %% [markdown]
# ### Validation

# %% [markdown]
# - First validation

# %%
print(len(raw))
raw.head()
# Out:
# 27
#    ï»¿CÃ³d. Unidade da FederaÃ§Ã£o  1Âº trimestre 2018  2Âº trimestre 2018  \
# 0        11              RondÃ´nia                2699                2663
# 1        12                   Acre                2352                2401
# 2        13               Amazonas                2442                2439
# 3        14                Roraima                3185                3059
# 4        15                  ParÃ¡                2109                2063
#
#    3Âº trimestre 2018  4Âº trimestre 2018  1Âº trimestre 2019  \
# 0                2787                2719                2601
# 1                2466                2476                2578
# 2                2321                2277                2335
# 3                3011                2976                2935
# 4                2096                2052                2082
#
#    2Âº trimestre 2019  3Âº trimestre 2019  4Âº trimestre 2019  \
# 0                2622                2739                2709
# ...

# %%
# Primeiras transformações realizadas na base
raw_change = raw.rename(columns={
    raw.columns[0]: "cod_uf",
    raw.columns[1]: "uf"
})
raw_change.columns = raw_change.columns.str.encode('latin1').str.decode('utf-8')
raw_change['uf'] = raw_change['uf'].str.encode('latin1').str.decode('utf-8')

# %%
print(len(raw_change))
raw_change.head()
# Out:
# 27
#    cod_uf        uf  1º trimestre 2018  2º trimestre 2018  3º trimestre 2018  \
# 0      11  Rondônia               2699               2663               2787
# 1      12      Acre               2352               2401               2466
# 2      13  Amazonas               2442               2439               2321
# 3      14   Roraima               3185               3059               3011
# 4      15      Pará               2109               2063               2096
#
#    4º trimestre 2018  1º trimestre 2019  2º trimestre 2019  3º trimestre 2019  \
# 0               2719               2601               2622               2739
# 1               2476               2578               2544               2510
# 2               2277               2335               2288               2352
# 3               2976               2935               3136               3146
# 4               2052               2082               2027               2093
#
# ...

# %%
diferencas = raw.reset_index(drop=True).equals(raw_change.reset_index(drop=True))
print(diferencas)
# Out:
# False

# %% [markdown]
# - Second Validation

# %%
anos = sorted(set([
    re.search(r'\d{4}', col).group()
    for col in raw_change.columns if re.search(r'\d{4}', col)
]))

# %%
for ano in anos:
    cols_ano = [col for col in raw_change.columns if ano in col]
    raw_change[ano] = raw_change[cols_ano].sum(axis=1)

# %%
raw_change.head()
# Out:
#    cod_uf        uf  1º trimestre 2018  2º trimestre 2018  3º trimestre 2018  \
# 0      11  Rondônia               2699               2663               2787
# 1      12      Acre               2352               2401               2466
# 2      13  Amazonas               2442               2439               2321
# 3      14   Roraima               3185               3059               3011
# 4      15      Pará               2109               2063               2096
#
#    4º trimestre 2018  1º trimestre 2019  2º trimestre 2019  3º trimestre 2019  \
# 0               2719               2601               2622               2739
# 1               2476               2578               2544               2510
# 2               2277               2335               2288               2352
# 3               2976               2935               3136               3146
# 4               2052               2082               2027               2093
#
# ...

# %%
anos = [2018, 2019]

for ano in anos:

    colunas_trimestre = [
        f"1º trimestre {ano}",
        f"2º trimestre {ano}",
        f"3º trimestre {ano}",
        f"4º trimestre {ano}"
    ]

    raw_change[f"check_{ano}"] = raw_change[colunas_trimestre].sum(axis=1)

    erros = raw_change[
        raw_change[str(ano)] != raw_change[f"check_{ano}"]
    ]

    print(f"Ano {ano} -> erros: {len(erros)}")
# Out:
# Ano 2018 -> erros: 0
# Ano 2019 -> erros: 0

# %%
raw_change["check_2022"] = (
    raw_change["2º trimestre 2022"] +
    raw_change["3º trimestre 2022"] +
    raw_change["4º trimestre 2022"]
)

raw_change[raw_change["2022"] != raw_change["check_2022"]]
# Out:
# Empty DataFrame
# Columns: [cod_uf, uf, 1º trimestre 2018, 2º trimestre 2018, 3º trimestre 2018, 4º trimestre 2018, 1º trimestre 2019, 2º trimestre 2019, 3º trimestre 2019, 4º trimestre 2019, 1º trimestre 2020, 2º trimestre 2022, 3º trimestre 2022, 4º trimestre 2022, 2018, 2019, 2020, 2022, check_2018, check_2019, check_2022]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# - Validar valores ausentes

# %%
anos = [2018, 2019, 2020, 2022]

for ano in anos:

    colunas_trimestre = [
        col
        for col in raw_change.columns
        if str(ano) in col and "trimestre" in col
    ]

    print(f"\n===== ANO {ano} =====")

    # quantidade de nulos por trimestre
    for coluna in colunas_trimestre:

        qtd_nulos = raw_change[coluna].isnull().sum()

        print(f"{coluna}: {qtd_nulos} nulos")

    # valida coluna anual
    if str(ano) in raw_change.columns:

        nulos_ano = raw_change[str(ano)].isnull().sum()

        print(f"Coluna {ano}: {nulos_ano} nulos")
# Out:
# ===== ANO 2018 =====
# 1º trimestre 2018: 0 nulos
# 2º trimestre 2018: 0 nulos
# 3º trimestre 2018: 0 nulos
# 4º trimestre 2018: 0 nulos
# Coluna 2018: 0 nulos
#
# ===== ANO 2019 =====
# 1º trimestre 2019: 0 nulos
# 2º trimestre 2019: 0 nulos
# 3º trimestre 2019: 0 nulos
# 4º trimestre 2019: 0 nulos
# Coluna 2019: 0 nulos
#
# ===== ANO 2020 =====
# 1º trimestre 2020: 0 nulos
# Coluna 2020: 0 nulos
#
# ===== ANO 2022 =====
# 2º trimestre 2022: 0 nulos
# 3º trimestre 2022: 0 nulos
# 4º trimestre 2022: 0 nulos
# Coluna 2022: 0 nulos

# %% [markdown]
# - Validação da soma anual

# %%
anos = [2018, 2019, 2020, 2022]

for ano in anos:

    colunas_trimestre = [
        col
        for col in raw_change.columns
        if str(ano) in col and "trimestre" in col
    ]

    raw_change[f"check_{ano}"] = (
        raw_change[colunas_trimestre]
        .sum(axis=1)
    )

    erros = raw_change[
        raw_change[str(ano)] !=
        raw_change[f"check_{ano}"]
    ]

    print(f"\nAno {ano}")
    print(f"Quantidade de erros: {len(erros)}")

    if len(erros) > 0:
        display(
            erros[
                ["uf", str(ano), f"check_{ano}"]
            ]
        )
# Out:
# Ano 2018
# Quantidade de erros: 0
#
# Ano 2019
# Quantidade de erros: 0
#
# Ano 2020
# Quantidade de erros: 0
#
# Ano 2022
# Quantidade de erros: 0
