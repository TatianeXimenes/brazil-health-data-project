# %% [markdown]
# # Standardization

# %%
import pandas as pd
import re

# %% [markdown]
# ## Leitura do arquivo

# %%
df = pd.read_csv(
    "/home/tatiane/repositorios/brazil-health-data-project/data_pipeline/data/raw/ibge_pnad_continua/tabela5436.csv",
    sep=",",
    encoding="latin1",
    #skiprows=10  # remove cabeçalho do SIDRA
)

# %%
print(len(df))
df.head()
# Out:
# 27
#    ï»¿CÃ³d. Unidade da FederaÃ§Ã£o  1Âº trimestre 2018  2Âº trimestre 2018  \
# 0        11              RondÃ´nia                2699                2663
# 1        12                   Acre                2352                2401
# 2        13               Amazonas                2442                2439
# 3        14                Roraima                3185                3059
# 4        15                  ParÃ¡                2109                2063
#
#    3Âº trimestre 2018  4Âº trimestre 2018  1Âº trimestre 2019  \
# 0                2787                2719                2601
# 1                2466                2476                2578
# 2                2321                2277                2335
# 3                3011                2976                2935
# 4                2096                2052                2082
#
#    2Âº trimestre 2019  3Âº trimestre 2019  4Âº trimestre 2019  \
# 0                2622                2739                2709
# ...

# %%
df = df.rename(columns={
    df.columns[0]: "cod_uf",
    df.columns[1]: "uf"
})

# %%
df.columns = df.columns.str.encode('latin1').str.decode('utf-8')
df['uf'] = df['uf'].str.encode('latin1').str.decode('utf-8')

# %% [markdown]
# - First validation

# %%
df.head()
# Out:
#    cod_uf        uf  1º trimestre 2018  2º trimestre 2018  3º trimestre 2018  \
# 0      11  Rondônia               2699               2663               2787
# 1      12      Acre               2352               2401               2466
# 2      13  Amazonas               2442               2439               2321
# 3      14   Roraima               3185               3059               3011
# 4      15      Pará               2109               2063               2096
#
#    4º trimestre 2018  1º trimestre 2019  2º trimestre 2019  3º trimestre 2019  \
# 0               2719               2601               2622               2739
# 1               2476               2578               2544               2510
# 2               2277               2335               2288               2352
# 3               2976               2935               3136               3146
# 4               2052               2082               2027               2093
#
# ...

# %%
anos = sorted(set([
    re.search(r'\d{4}', col).group()
    for col in df.columns if re.search(r'\d{4}', col)
]))

# %%
for ano in anos:
    cols_ano = [col for col in df.columns if ano in col]
    df[ano] = df[cols_ano].sum(axis=1)

# %% [markdown]
# - Second validation

# %%
df.head()
# Out:
#    cod_uf        uf  1º trimestre 2018  2º trimestre 2018  3º trimestre 2018  \
# 0      11  Rondônia               2699               2663               2787
# 1      12      Acre               2352               2401               2466
# 2      13  Amazonas               2442               2439               2321
# 3      14   Roraima               3185               3059               3011
# 4      15      Pará               2109               2063               2096
#
#    4º trimestre 2018  1º trimestre 2019  2º trimestre 2019  3º trimestre 2019  \
# 0               2719               2601               2622               2739
# 1               2476               2578               2544               2510
# 2               2277               2335               2288               2352
# 3               2976               2935               3136               3146
# 4               2052               2082               2027               2093
#
# ...

# %%
cols_trimestres = [col for col in df.columns if 'trimestre' in col]
df = df.drop(columns=cols_trimestres)

# %%
df_long = df.melt(
    id_vars=['cod_uf', 'uf'],
    var_name='ano',
    value_name='renda_media'
)

# %% [markdown]
# - Third validation

# %%
print(len(df_long))
df_long.head()
# Out:
# 108
#    cod_uf        uf   ano  renda_media
# 0      11  Rondônia  2018        10868
# 1      12      Acre  2018         9695
# 2      13  Amazonas  2018         9479
# 3      14   Roraima  2018        12231
# 4      15      Pará  2018         8320

# %% [markdown]
# ### Writing the dataset

# %%
df_long.to_parquet('/home/tatiane/repositorios/brazil-health-data-project/data_pipeline/data/processed/ibge_pnad_continua/ibge_pnad_continua.parquet', index=False)
