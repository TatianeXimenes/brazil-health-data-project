# %% [markdown]
# # Conversion

# %%
import pandas as pd

# %%
# Reading
df = pd.read_excel('/home/tatiane/repositorios/brazil-health-data-project/data_pipeline/data/raw/ibge_codigos/RELATORIO_DTB_BRASIL_2024_MUNICIPIOS.xls')

# %%
# Conversion
df.to_parquet('/home/tatiane/repositorios/brazil-health-data-project/data_pipeline/data/raw/ibge_codigos/conversion/dtb_brasil_2024_municipios.parquet', engine='pyarrow')
